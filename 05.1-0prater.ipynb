# %% [markdown]
# # arithmetic opration

# %% [markdown]
# # addition , substraction , multiplication , division , modulues, exponentiation

# %%
a = 11
b = 5

# %%
a+b
# Out:
# 16

# %%
a-b
# Out:
# 6

# %%
a*b
# Out:
# 55

# %%
a/b
# Out:
# 2.2

# %%
a//b
# Out:
# 2

# %%
2**2
# Out:
# 4

# %%
a/b
# Out:
# 2.2

# %% [markdown]
# # comparision opration
#   ## to check
#  ## true
#  ## false

# %%
a=10
b=6

# %%
a=45
b=4

# %%
a>b
# Out:
# True

# %%
a<b
# Out:
# False

# %%
a<=b
# Out:
# False

# %%
a>=b
# Out:
# True

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
a=5
b=5

# %%
a==c
# Out:
# False

# %%
a!=c
# Out:
# True

# %%
c=3
a=4

# %%
a==b
# Out:
# True

# %%
a>=b
# Out:
# True

# %%
a<=b
# Out:
# True

# %% [markdown]
#  # logic opration

# %%
## use to combine conditional statement

# %%
b1 = True
b2 = False

# %%
not(b2)
# Out:
# True

# %%
not(b1)
# Out:
# False

# %%
b1 or b2
# Out:
# True

# %%
b1 and b2
# Out:
# False

# %% [markdown]
# # bitwise opration
# ## perform bit-level

# %%
a=5
b=3

# %%
a&b
# Out:
# 1

# %%
a|b
# Out:
# 7

# %% [markdown]
# # Assignment

# %%
a= 10

# %%
a += 4

# %%
a
# Out:
# 14

# %%
a -=4

# %%
a
# Out:
# -54

# %%
a=34

# %%
a *=4

# %%
a
# Out:
# 136

# %%
a /=2
a
# Out:
# 68.0

# %%
11 // 2
# Out:
# 5

# %%
a // 2
# Out:
# 34.0

# %%
a = 11

# %%
a //=2
a
# Out:
# 5
