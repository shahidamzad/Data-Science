# %% [markdown]
# # Tuples & Tuples methods
# ### tuple is an ordered , immutable collection of data

# %%
e = ()

# %%
e
# Out:
# ()

# %%
type(e)
# Out:
# tuple

# %%
type(1)
# Out:
# int

# %%
l=[]

# %%
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
t=(3,4,5,6,7,8)

# %%
t
# Out:
# (3, 4, 5, 6, 7, 8)

# %%
t[0]
# Out:
# 3

# %%
t[1]
# Out:
# 4

# %%
print(t[5])
# Out:
# 8

# %%
t[1] =34
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 t[1] =34
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # Tuple packing and unpacking

# %%
person = ("shahid" ,23,"enginner")  # packing

#unpacking
name,age,profession = person

# %%
name
# Out:
# 'shahid'

# %%
age
# Out:
# 23

# %%
profession
# Out:
# 'enginner'

# %% [markdown]
# # Common tuple method
# #### 1. count(x) -- return the number of time .
# #### 2. index(x) -- return the index of the first occurence of x.
