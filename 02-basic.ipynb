# %% [markdown]
# # string & method

# %%
name='shahid'

# %%
name
# Out:
# 'shahid'

# %% [markdown]
#  # method

# %%
name.upper() # convert into upper case
# Out:
# 'SHAHID'

# %%
name.endswith("d") # to check end word is true or false
# Out:
# True

# %%
name.endswith('the')
# Out:
# False

# %%
name.count("h") #use to find charecter in words
# Out:
# 2

# %%
print(len(name)) # to find length of string
# Out:
# 6

# %%
print(name.strip())   # to remove space use .strip() fun
# Out:
# shahid

# %% [markdown]
# # length

# %%
s= "shahidhussain"

# %%
print(len(s))
# Out:
# 13

# %%
s[0:5]
# Out:
# 'shahi'

# %%
s[1:-1]
# Out:
# 'hahidhussai'

# %%
s[1:12]
# Out:
# 'hahidhussai'
