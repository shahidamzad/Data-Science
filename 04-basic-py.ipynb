# %% [markdown]
# # Taking input from the user

# %%
a = input("Enter the value of a" ) # by defalut take  user input as a string
# Out:
# Enter the value of a 857

# %%
a
# Out:
# '857'

# %%
b = input("Enter the value of b" )
# Out:
# Enter the value of b 87

# %%
b
# Out:
# '87'

# %%
a+b
# Out:
# '85787'

# %%
(int(a) + int(b))
# Out:
# 944

# %%
c = input()
# Out:
#  54

# %%
c
# Out:
# '54'
