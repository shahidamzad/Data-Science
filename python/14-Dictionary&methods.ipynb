# %% [markdown]
# # Dictionary & Methods
# #### Dictionary is an unorderd ,mutable and key-value pair of collectoin . It allow efficient data retrival and modification

# %%
#creating a Dictionary 

empty_dict = {}

# Dictionary with key-value pairs
student={
    "name" : "shahid",
    "age" : 23,
    "grade" : "A" 
}

# %%
 d = {}

# %%
type(d)
# Out:
# dict

# %%
student={
    "name" : "shahid",
    "age" : 23,
    "grade" : "A"
}

# %%
student['name']
# Out:
# 'shahid'

# %%
student['age']
# Out:
# 23

# %%
student['grade']
# Out:
# 'A'

# %%
# Updating an existing value 

#Dictionary with key-value pairs
student={
    "name" : "shahid",
    "age" : 23,
    "grade" : "A" 
}

# %%
print(student['age'])
# Out:
# 23

# %%
# Updating an existing value 
student['age'] = 25

# %%
student  # here  chanded studend age
# Out:
# {'name': 'shahid', 'age': 25, 'grade': 'A'}

# %%
# keys method 
student.keys()
# Out:
# dict_keys(['name', 'age', 'grade'])

# %%
# values method
student.values()
# Out:
# dict_values(['shahid', 25, 'A'])

# %%
# items method = return key-value pair as tupple
student.items()
# Out:
# dict_items([('name', 'shahid'), ('age', 25), ('grade', 'A')])

# %%
# update method 
student.update({'name' : 'nahid' })

# %%
student
# Out:
# {'name': 'nahid', 'age': 25, 'grade': 'A'}

# %%
student.update({'name' : 'Tannu', 'language': 'java-script' })

# %%
student
# Out:
# {'name': 'Tannu', 'age': 25, 'grade': 'A', 'language': 'java-script'}

# %%
# pop method
student.pop("name")
# Out:
# 'Tannu'

# %%
student
# Out:
# {'age': 25, 'grade': 'A', 'language': 'java-script'}

# %%
student.popitem()
# Out:
# ('grade', 'A')

# %%
student.clear()

# %%
student
# Out:
# {}

# %%
student={
    "name" : "shahid",
    "age" : 23,
    "grade" : "A" 
}

# %%
student.copy()
# Out:
# {'name': 'shahid', 'age': 23, 'grade': 'A'}
