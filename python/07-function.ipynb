# %% [markdown]
# # Function in python

# %%
def avg(a,b):
    return (a+b)/2

# %%
avg(2,9)
# Out:
# 5.5

# %% [markdown]
# # passing defult argument
#
# ## defult argument used in end

# %%
def avg(a , b=30):
    return(a-b)*4

# %%
avg(25)
# Out:
# -20

# %%
def greet():
    print("good morning")

# %%
greet()
# Out:
# good morning
