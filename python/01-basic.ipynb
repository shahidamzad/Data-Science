# %% [markdown]
# # variable

# %%
a=57

# %%
b=32

# %%
a+b
# Out:
# 89

# %% [markdown]
# # string

# %%
a= "shahid"

# %%
b="hussain"

# %%
a+b
# Out:
# 'shahidhussain'

# %%
 a+b # this is print a and b cobine togather
# Out:
# 'shahidhussain'

# %% [markdown]
# # type

# %%
name ="shahid"

# %%
x=10

# %%
b=3.14

# %%
print(type(a))
print(type(b))
# Out:
# <class 'str'>
# <class 'float'>

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(type(b))
# Out:
# <class 'float'>

# %% [markdown]
# # typecasting

# %%
a="4643"

# %%
b="3745"

# %%
print (a+b)
# Out:
# 46433745

# %%
print(int(a) + int(b))
# Out:
# 8388
