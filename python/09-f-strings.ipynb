# %% [markdown]
# # String Fromatting in python

# %%
name = "Shahid"
age = 23
print("my name is {} and i am {} year old.".format(name,age))
# Out:
# my name is Shahid and i am 23 year old.

# %%
s =  "shahid"

# %%
s[0]
# Out:
# 's'

# %%
s.upper()
# Out:
# 'SHAHID'

# %%
s
# Out:
# 'shahid'

# %% [markdown]
# # String format()

# %%
name = "Sid"
age = 23
print("my name is {} and i am {} year old.".format(name,age))
# Out:
# my name is Sid and i am 23 year old.

# %%
print(f"my name is {name} and i am {age} year old.")
# Out:
# my name is Sid and i am 23 year old.

# %% [markdown]
#  # Expression inside f-string

# %%
a = 15
b = 10

# %%
print(f"sum of {a} and {b } is {a+b}")
# Out:
# sum of 15 and 10 is 25

# %% [markdown]
# # Formatting number

# %%
pi = 3.14159

# %%
print(f"pi roundede to 2 decimal place : {pi:.2f}")
# Out:
# pi roundede to 2 decimal place : 3.14

# %% [markdown]
# # padding and alinement

# %%
print(f"{'python':>10}")
print(f"{'python':<10}")
print(f"{'python':^10}")
# Out:
#     python
# python
#   python
