# %% [markdown]
# # Match
# ### make if else easy

# %%
def http_status(code):
    match code:
        case 200:
            return "ok"
        case 400:
            return "bad request"
        case 500:
           return "internal server erorr"
        case _:
            return 'unknown status'

# %%
case = 500

# %%
match case:
    case 400:
       print("bad response")
       print("good joob")
    case 404:
        print("not found")
    case _:
        print("not match")
# Out:
# not match
