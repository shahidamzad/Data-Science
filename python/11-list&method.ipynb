# %% [markdown]
# # Python list & list method
# ### list method are muteable

# %%
l = [3,4,6,78,9,6]

# %%
l[0]
# Out:
# 3

# %%
l[2]
# Out:
# 6

# %%
l[5]
# Out:
# 6

# %%
l[0] = 2 # replaceing the 0 index  of list , muteable list

# %%
l
# Out:
# [2, 4, 6, 78, 9, 6]

# %%
# append method
l.append(9)

# %%
l
# Out:
# [2, 4, 6, 78, 9, 6, 9]

# %%
l2 =[ 5,7]

# %%
#extend method
l.extend(l2)

# %%
l
# Out:
# [2, 4, 6, 78, 9, 6, 9, 5, 7]

# %%
# insert method 
l.insert(1,200)

# %%
l
# Out:
# [2, 200, 4, 6, 78, 9, 6, 9, 5, 7]

# %%
# pop method
l.pop(4)
# Out:
# 78

# %%
l
# Out:
# [2, 200, 4, 6, 9, 6, 9, 5, 7]

# %%
number = l.pop(4)

# %%
number
# Out:
# 9

# %%
# index method
l.index(4)
# Out:
# 2

# %%
l.append(4)

# %%
l
# Out:
# [2, 200, 4, 6, 6, 9, 5, 7, 4]

# %%
# count method
l.count(4)
# Out:
# 2

# %%
# sort method
l.sort() # changes and sort the original list in assending order

# %%
l
# Out:
# [2, 4, 4, 5, 6, 6, 7, 9, 200]

# %%
sorted(l)
# Out:
# [2, 4, 4, 5, 6, 6, 7, 9, 200]

# %%
newl = [22,226,8555,58,2,1,3]

# %%
sorted(newl) # retrun a new list which is sorted versionof the original list
# Out:
# [1, 2, 3, 22, 58, 226, 8555]

# %%
newl
# Out:
# [22, 226, 8555, 58, 2, 1, 3]

# %% [markdown]
# # Nested list

# %%
y = [1,2,4,6,True, False,[33,55]]

# %%
y
# Out:
# [1, 2, 4, 6, True, False, [33, 55]]

# %%
y[6]
# Out:
# [33, 55]

# %%
y[6][1]
# Out:
# 55

# %% [markdown]
# # List concatenation

# %%
list1 =[1,3,4,5]

# %%
list2 =[2,6,8,9]

# %%
list1 + list2
# Out:
# [1, 3, 4, 5, 2, 6, 8, 9]

# %%
list1
# Out:
# [1, 3, 4, 5]

# %%
list2
# Out:
# [2, 6, 8, 9]

# %%
if 3 in list1:
    print("yes")
# Out:
# yes

# %%
3 in list2
# Out:
# False

# %%
3 in list1
# Out:
# True

# %%
# split function
s = 'shahid-nahid-arman-asad-irshad'

# %%
s.split("-")
# Out:
# ['shahid', 'nahid', 'arman', 'asad', 'irshad']
