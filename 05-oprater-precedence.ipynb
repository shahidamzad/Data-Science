# %% [markdown]
# # oprater precedence in python

# %% [markdown]
# ## python follow PEDMAS rule
# ### parenthises , expenent , multiplication , division , addition , substraction

# %%
result = 10+2*3 
print(result)
# Out:
# 16

# %%
result = (10+2) *3
print(result)
# Out:
# 36

# %%
result = 2 ** 3 ** 2
print(result)
# Out:
# 512
